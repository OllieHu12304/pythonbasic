# %% [markdown]
# ##### Class 設計

# %% [markdown]
# ##### 繼承

# %%
class Vehicle:
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model
    def display_info(self):
        return f"Brand: {self.brand}, Model: {self.model}"
   
 
class Car(Vehicle):
    def __init__(self, brand, model, car_type):
        self.brand = brand
        self.model = model
        # super().__init__(brand, model)
        self.car_type = car_type
    # def display_info(self):
    #     return f"Brand: {self.brand}, Model: {self.model}, Car_Type: {self.car_type}"
 
car1 = Car('Toyota', 'Camry', 'Bus')
print(car1.brand)
print(car1.display_info())
