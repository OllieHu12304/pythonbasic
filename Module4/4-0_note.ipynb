# %% [markdown]
# |型態| 創建方式 | 可否修改 | 有序/無序 | 可否重複 |
# |:---:|:---:|:---:|:---:|:---:|
# |str|`name="Ollie"`| ❌ | ✅ | ✅ |
# |list|`list=[1, 2, 3]` |✅ |✅ | ✅ |
# |dict|`dict={'name': 'Ollie', 'age', 29}` |✅ |✅ | Key ❌ / Value ✅  |
# |tuple|`tuple=(1, 2, 3)` |❌ |✅ | ✅ |
# |set|`set={1, 2, 3}` |✅ |❌ | ❌ |

# %%
# 呼叫emoji
# Windows + ; 
# Control (^) + Command (⌘) + 空白鍵

# %%
set = {1, 2, 3}
print(set[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 set = {1, 2, 3}
# ----> 2 print(set[0])
#
# TypeError: 'set' object is not subscriptable
